# %%
import pandas as pd
import numpy as np
df = pd.read_csv("DM2021_fktpnonkapitasi.csv")

# %%
print(df.dtypes)
# Out:
# Unnamed: 0      int64
# PSTV01          int64
# PSTV02          int64
# PSTV15        float64
# PNK02          object
# PNK03          object
# PNK04          object
# PNK05          object
# PNK06          object
# PNK07          object
# PNK08          object
# PNK09          object
# PNK10          object
# PNK11          object
# PNK12          object
# PNK13          object
# PNK13A         object
# PNK14          object
# PNK15          object
# PNK16          object
# PNK17           int64
# PNK18           int64
# PNK19         float64
# PNK20         float64
# dtype: object

# %%
df.describe()
# Out:
#         Unnamed: 0        PSTV01        PSTV02       PSTV15          PNK17  \
# count  1368.000000  1.368000e+03  1.368000e+03  1368.000000    1368.000000
# mean    691.747807  6.334784e+07  8.226461e+07    10.438612   56556.673977
# std     398.830146  7.201695e+07  1.106321e+08     3.634073   56170.589770
# min       5.000000  1.276117e+06  1.276117e+06     1.115794   10000.000000
# 25%     347.750000  2.536801e+07  2.086732e+07     9.339209   30000.000000
# 50%     689.500000  5.013406e+07  5.236158e+07    11.736576   45000.000000
# 75%    1032.250000  7.687895e+07  7.849861e+07    12.950229   60000.000000
# max    1670.000000  4.120936e+08  4.550712e+08    14.071786  950000.000000
#
#                PNK18         PNK19   PNK20
# count    1368.000000   1368.000000  1368.0
# mean    56556.673977    111.962361     0.0
# std     56170.589770    357.611764     0.0
# min     10000.000000      0.000000     0.0
# 25%     30000.000000     18.000000     0.0
# ...

# %%
df.head()
# Out:
#    Unnamed: 0    PSTV01    PSTV02     PSTV15             PNK02       PNK03  \
# 0           5  81015840  81015840   6.769341  422320721P000720  2021-07-10
# 1           7  29370125  29370125  12.620406  340880321P002999  2021-03-25
# 2           8   7662814   7662814  12.128812  222771121P000527  2021-11-21
# 3           9  53019648  53019648  14.044061   75110521P000245  2021-05-19
# 4          10  49961851  78498608  13.067945  136460221P000198  2021-02-04
#
#         PNK04       PNK05           PNK06            PNK07  ...  \
# 0  2021-07-10  2021-07-10            ACEH  ACEH BARAT DAYA  ...
# 1  2021-03-25  2021-03-25            ACEH       ACEH UTARA  ...
# 2  2021-11-21  2021-11-21  SULAWESI BARAT  POLEWALI MANDAR  ...
# 3  2021-05-19  2021-05-19      JAWA BARAT     KOTA BANDUNG  ...
# 4  2021-02-04  2021-02-04      JAWA TIMUR           JEMBER  ...
#
#            PNK12                                              PNK13 PNK13A  \
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0    0
# PSTV01        0
# PSTV02        0
# PSTV15        0
# PNK02         0
# PNK03         0
# PNK04         0
# PNK05         0
# PNK06         0
# PNK07         0
# PNK08         0
# PNK09         0
# PNK10         0
# PNK11         0
# PNK12         0
# PNK13         0
# PNK13A        0
# PNK14         0
# PNK15         0
# PNK16         0
# PNK17         0
# PNK18         0
# PNK19         0
# PNK20         0
# dtype: int64

# %%
df.sample(5)
# Out:
#       Unnamed: 0    PSTV01    PSTV02     PSTV15             PNK02       PNK03  \
# 1162        1169  61827760  61827760  10.808723   80431021P000581  2021-10-30
# 220          226   7943230  55823305  11.252802  253520221P000189  2021-02-16
# 330          336  89414688  34026900  11.003674   44780921P000976  2021-09-16
# 15            21  25797363  25797363  13.108784  371290421P000349  2021-04-12
# 719          725  68204935  68204935  10.678030  315900721P012565  2021-07-20
#
#            PNK04       PNK05        PNK06          PNK07  ...          PNK12  \
# 1162  2021-10-30  2021-10-30  JAWA TENGAH           PATI  ...           PBPU
# 220   2021-02-16  2021-02-16  JAWA TENGAH       GROBOGAN  ...       PBI APBN
# 330   2021-09-16  2021-09-16   JAWA BARAT        CIREBON  ...           PBPU
# 15    2021-04-12  2021-04-12  JAWA TENGAH     KOTA TEGAL  ...  BUKAN PEKERJA
# 719   2021-07-20  2021-07-20  JAWA TENGAH  KOTA SEMARANG  ...           PBPU
#
# ...

# %%
total = df.isnull().sum().sort_values(ascending=False)

percent = (df.isnull().sum()/df.isnull().count()) \
.sort_values(ascending=False)

missing_data = pd.concat([total, percent], axis=1, \
                        keys=['Total', 'Missing Percent'])

missing_data['Missing Percent'] = \
missing_data['Missing Percent'].apply(lambda x: x*100)

missing_data.loc[missing_data['Missing Percent'] > 10][:10]
# Out:
# Empty DataFrame
# Columns: [Total, Missing Percent]
# Index: []

# %%
df.shape
# Out:
# (1368, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1368 entries, 0 to 1367
# Data columns (total 24 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1368 non-null   int64
#  1   PSTV01      1368 non-null   int64
#  2   PSTV02      1368 non-null   int64
#  3   PSTV15      1368 non-null   float64
#  4   PNK02       1368 non-null   object
#  5   PNK03       1368 non-null   object
#  6   PNK04       1368 non-null   object
#  7   PNK05       1368 non-null   object
#  8   PNK06       1368 non-null   object
#  9   PNK07       1368 non-null   object
#  10  PNK08       1368 non-null   object
#  11  PNK09       1368 non-null   object
#  12  PNK10       1368 non-null   object
#  13  PNK11       1368 non-null   object
#  14  PNK12       1368 non-null   object
#  15  PNK13       1368 non-null   object
#  16  PNK13A      1368 non-null   object
#  17  PNK14       1368 non-null   object
#  18  PNK15       1368 non-null   object
# ...

# %% [markdown]
# ## Validasi Data

# %%
df['PSTV15'].describe()
# Out:
# count    1368.000000
# mean       10.438612
# std         3.634073
# min         1.115794
# 25%         9.339209
# 50%        11.736576
# 75%        12.950229
# max        14.071786
# Name: PSTV15, dtype: float64

# %%
df['PSTV15'].hist(edgecolor='black', bins=20);

# %%
df['PNK18'].describe()
# Out:
# count      1368.000000
# mean      56556.673977
# std       56170.589770
# min       10000.000000
# 25%       30000.000000
# 50%       45000.000000
# 75%       60000.000000
# max      950000.000000
# Name: PNK18, dtype: float64

# %%
df['PNK18'].hist(edgecolor='black', bins=20);
